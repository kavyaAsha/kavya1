# %%
import pandas as pd
import matplotlib.pyplot as plt
df1=pd.read_csv('C:/Users/Admin/Desktop/kavya/mtcars.csv')
df1
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
fig=plt.figure(figsize=[3,3])
ax=fig.add_axes([0,0,1,1])
ax.set_title("distribution of variable",fontsize=16)
ax.set_xlabel("miles per gallon",fontsize=12)
ax.set_ylabel("frequency",fontsize=12)
ax.hist(df1['mpg'],color='C4',bins=10)
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7444\2944257979.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[3,3])
ax=fig.add_axes([0,0,1,1])
ax.set_title("distribution of variable",fontsize=16)
ax.set_xlabel("interval",fontsize=12)
ax.set_ylabel("frequency",fontsize=12)
ax.scatter(df1['mpg'],df1['wt'],color='C3')
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7444\2490821679.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[3,3])
ax=fig.add_axes([0,0,1,1])
ax.set_title("distribution of variable",fontsize=16)
ax.set_xlabel("model",fontsize=12)
ax.set_ylabel("frequency",fontsize=12)
ax.plot(df['mpg'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7444\2255400738.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[3,3])
ax=fig.add_axes([0,0,1,1])
ax.set_title("distribution of variable",fontsize=16)
ax.set_xlabel("type",fontsize=12)
ax.set_ylabel("frequency",fontsize=12)
ax.bar(df1['mpg'],df1['am'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7444\261689206.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[3,3])
ax=fig.add_axes([0,0,1,1])
ax.set_title("distribution of variable",fontsize=16)
ax.set_xlabel("wt",fontsize=12)
ax.set_ylabel("frequency",fontsize=12)
ax.boxplot(df1['mpg'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7444\3562005666.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import pandas as pd
df=pd.DataFrame({'book-name':['book1','book2','book3','book4','book1','book2','book3','book5'],
    'book-type':['math','physics','computer','science','math','physics','computer','english'],
    'book-id':[1,2,3,4,1,2,3,5]})
print(df)
# Out:
#   book-name book-type  book-id
# 0     book1      math        1
# 1     book2   physics        2
# 2     book3  computer        3
# 3     book4   science        4
# 4     book1      math        1
# 5     book2   physics        2
# 6     book3  computer        3
# 7     book5   english        5

# %%
df.describe()
# Out:
#         book-id
# count  8.000000
# mean   2.625000
# std    1.407886
# min    1.000000
# 25%    1.750000
# 50%    2.500000
# 75%    3.250000
# max    5.000000

# %%
df.agg(['count'])
# Out:
#        book-name  book-type  book-id
# count          8          8        8

# %%
df.agg(['min','max','median'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7444\3249242962.py:1: FutureWarning: ['book-name', 'book-type'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.agg(['min','max','median'])
#        book-name book-type  book-id
# min        book1  computer      1.0
# max        book5   science      5.0
# median       NaN       NaN      2.5

# %%
df.sum()
# Out:
# book-name             book1book2book3book4book1book2book3book5
# book-type    mathphysicscomputersciencemathphysicscomputere...
# book-id                                                     21
# dtype: object

# %%
result=df.groupby(["book_name","book_type"])["book_type"].count()reset_index(name='count')
result
# Out:
#   Input In [105]
#     result=df.groupby(["book_name","book_type"])["book_type"].count()reset_index(name='count')
#                                                                      ^
# SyntaxError: invalid syntax
